# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 1.Dataset Importing

# %%
 data=pd.read_csv('Predicting heart disease.csv')
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## There is no catagorical value in our dataset. There is no need handle catagorical variable

# %% [markdown]
# ## 2.Perform univariate and bivariate analysis and derive meaningful insights about the dataset

# %%
# seperating each attribute along with the target value
predictingValue = data.target
# having all the attributes in seperate variables that can be used for bi as well as univariate analysis
y = data.age
y1 =data.sex
y2 = data.cp
y3 =data.trestbps
y4 = data.chol
y5 = data.fbs
y6 = data.restecg
y7 = data.thalach
y8 =data.exang
y9 = data.oldpeak
y10 = data.slope
y11 = data.ca
y12 = data.thal

# %% [markdown]
# ## plotting target value with each attribute

# %%
sns.barplot(data.target,y,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y1,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y2,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y3,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y4,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y5,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y6,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
sns.barplot(data.target,y7,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.show()

# %% [markdown]
# ## Handling and analysis outlier

# %%
sns.boxplot(data.target,y,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ## Attribute : Age
# ## For 0 : 1 outlier
# ## For 1 : 0 outlier

# %%
sns.boxplot(data.target,y1,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : Sex
# ### For 0 : 3 outlier
# ### For 1 : 0 outlier

# %%
sns.boxplot(data.target,y2,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : cp
# ### For 0 : 2 outlier
# ### For 1 : 2 outlier¶

# %%
sns.boxplot(data.target,y3,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : trestbps
# ### For 0 : 2 outlier
# ### For 1 : 2 outlier

# %%
sns.boxplot(data.target,y4,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : chol
# ### for 0 : 1 outlier
# ### For 1 : 3 outlier

# %%
sns.boxplot(data.target,y5,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ###  Attribute : fbs
# ### For 0 : 1 outlier
# ### For 1 : 1 outlier¶

# %%
sns.boxplot(data.target,y9,hue=data.target,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %%
corr=data.corr()
corr
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
data.hist()
plt.show()

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ## this heat map show that target value is show positive corr with chest pain

# %% [markdown]
# ## Build a correlation matrix to identify relevant variables

# %%
target_value=data['cp']
chest_pain=data["target"]
np.corrcoef(target_value,chest_pain)
plt.scatter(target_value,chest_pain)
plt.show()

# %%
target_value=data['age']
chest_pain=data["oldpeak"]
np.corrcoef(target_value,chest_pain)
plt.scatter(target_value,chest_pain)
plt.show()

# %% [markdown]
# ## this is show that age and oldpeak have positive corr

# %%
sns.set_style('whitegrid')
sns.countplot(x='target',data=data,palette='RdBu_r')

# %% [markdown]
# ## it show that the target class are of equal size

# %%
sns.pairplot(data)
plt.show()
